# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51541/ADM/blob/main/LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Apply PCA to reduce the high-dimensional performance metrics to 2 components.
# 2.	Plot the PCA results using a scatter plot, coloring points based on job roles

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
#TO READ CSV FILE
data = pd.read_csv("/content/employee_performance.csv")

# %%
#TO STANDARDIZE DATASET
scaler = StandardScaler()
data_scaled=scaler.fit_transform(data)
data
# Out:
#     Employee ID  Work Hours  Projects Completed  Satisfaction Level  Experience (Years)
# 0             1          40                   5                 4.2                   3
# 1             2          38                   7                 4.5                   5
# 2             3          42                   4                 3.8                   2
# 3             4          35                   6                 4.1                   4
# 4             5          45                   8                 4.7                   6
# ..          ...         ...                 ...                 ...                 ...
# 95           96          37                   6                 4.0                   4
# 96           97          41                   7                 4.5                   6
# 97           98          36                   5                 3.9                   3
# 98           99          42                   8                 4.6                   5
# ...

# %%
#PERFORMING PCA
pca=PCA(n_components=2)
principle_compnents=pca.fit_transform(data_scaled)
data_scaled
# Out:
# array([[-1.71481604,  0.17518073, -1.19915853, -0.30381372, -1.24644541],
#        [-1.68017329, -0.63961335,  0.26322992,  0.76847001,  0.35156152],
#        [-1.64553055,  0.98997481, -1.93035276, -1.73352536, -2.04544887],
#        [-1.6108878 , -1.86180448, -0.4679643 , -0.66124163, -0.44744194],
#        [-1.57624505,  2.21216593,  0.99442415,  1.48332583,  1.15056499],
#        [-1.5416023 , -1.0470104 , -1.19915853, -1.01866954, -1.24644541],
#        [-1.50695955,  0.17518073,  1.72561837,  2.19818165,  1.94956845],
#        [-1.4723168 , -0.23221631, -0.4679643 ,  0.05361419,  0.35156152],
#        [-1.43767406,  0.58257777,  0.26322992,  1.12589792,  1.15056499],
#        [-1.40303131, -1.45440744, -1.19915853, -1.37609745, -0.44744194],
#        [-1.36838856,  1.39737185,  0.99442415,  0.4110421 ,  0.35156152],
#        [-1.33374581, -0.23221631, -0.4679643 , -0.30381372, -0.44744194],
#        [-1.29910306, -0.63961335,  0.26322992,  0.05361419,  0.35156152],
# ...

# %%
#TO CONVERT IN DATAFRAME
df=pd.DataFrame(principle_compnents,columns=['PC1','PC2'])
df
# Out:
#          PC1       PC2
# 0  -1.307198 -1.753698
# 1   0.378306 -1.675800
# 2  -2.409577 -1.688494
# 3  -1.713860 -1.562718
# 4   2.897006 -1.632441
# ..       ...       ...
# 95 -1.477547  1.611053
# 96  1.395135  1.579378
# 97 -2.623924  1.672272
# 98  1.745552  1.660257
# 99 -0.714020  1.708442
#
# [100 rows x 2 columns]

# %%
#TO PLOT SCATTER PLOT
plt.figure(figsize=(10,10))
plt.scatter(df['PC1'],df['PC2'])
plt.xlabel('principal compnent 1')
plt.ylabel('principal compnent 2')
plt.title('Principle Component Analysis')
plt.grid()
plt.show()
